# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# # Latihan

# %%
run("SHOW TABLES")
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %%
run("SHOW COLUMNS FROM payments")
# Out:
#             Field           Type Null  Key Default Extra
# 0  customerNumber        int(11)   NO  PRI    None
# 1     checkNumber    varchar(50)   NO  PRI    None
# 2     paymentDate           date   NO         None
# 3          amount  decimal(10,2)   NO         None

# %%
run("SELECT * FROM customers ORDER BY customerName")
# Out:
#      customerNumber                        customerName contactLastName  \
# 0               242                        Alpha Cognac          Roulet
# 1               168              American Souvenirs Inc          Franco
# 2               249                  Amica Models & Co.         Accorti
# 3               237                       ANG Resellers          Camino
# 4               276             Anna's Decorations, Ltd          O'Hara
# 5               465                 Anton Designs, Ltd.           Anton
# 6               206          Asian Shopping Network, Co          Walker
# 7               348               Asian Treasures, Inc.         McKenna
# 8               103                   Atelier graphique         Schmitt
# 9               471        Australian Collectables, Ltd        Clenahan
# 10              114          Australian Collectors, Co.        Ferguson
# 11              333         Australian Gift Network, Co        Calaghan
# ...

# %% [markdown]
# # One to many relationship

# %% [markdown]
# ## 1. Report the account representative for each customer.

# %%
# Termasuk customer yang belum memiliki account representative agar lebih informatif
run("""
    SELECT
    customerNumber,
    customerName,
    employeeNumber,
    CONCAT(firstName, lastName)
    FROM
    customers c
    LEFT JOIN 
    employees e
    ON c.salesRepEmployeeNumber = e.employeeNumber
    ORDER BY employeeNumber DESC
""")
# Out:
#      customerNumber                        customerName  employeeNumber  \
# 0               216                  Enaco Distributors          1702.0
# 1               376               Precious Collectables          1702.0
# 2               458          Corrida Auto Replicas, Ltd          1702.0
# 3               298                     Vida Sport, Ltd          1702.0
# 4               344                         CAF Imports          1702.0
# 5               484          Iberia Gift Imports, Corp.          1702.0
# 6               398             Tokyo Collectables, Ltd          1621.0
# 7               148             Dragon Souveniers, Ltd.          1621.0
# 8               211         King Kong Collectables, Co.          1621.0
# 9               177                Osaka Souveniers Co.          1621.0
# 10              385                     Cruz & Sons Co.          1621.0
# 11              323          Down Under Souveniers, Inc          1612.0
# ...

# %% [markdown]
# ## 2. Report total payments for Atelier graphique.

# %%
run("""
    SELECT
    c.customerNumber,
    customerName,
    SUM(amount)
    FROM
    customers c
    INNER JOIN
    payments p
    ON c.customerNumber = p.customerNumber
    WHERE c.customerNumber = '103'
    
""")
# Out:
#    customerNumber       customerName  SUM(amount)
# 0             103  Atelier graphique     22314.36

# %% [markdown]
# ## 3. Report the total payments by date

# %%
run("""
    SELECT
    paymentDate,
    SUM(amount)
    FROM
    payments
    GROUP BY paymentDate
    ORDER BY paymentDate
""")
# Out:
#     paymentDate  SUM(amount)
# 0    2003-01-16     10223.83
# 1    2003-01-28     10549.01
# 2    2003-01-30      5494.78
# 3    2003-02-16     50218.95
# 4    2003-02-20     53959.21
# 5    2003-02-25     40206.20
# 6    2003-03-02     52151.81
# 7    2003-03-09     51001.22
# 8    2003-03-12     22292.62
# 9    2003-03-20     25833.14
# 10   2003-03-27     48425.69
# 11   2003-04-09     24212.79
# 12   2003-04-11     11044.30
# 13   2003-04-16     21665.98
# 14   2003-04-19      1627.56
# 15   2003-04-20     33383.14
# 16   2003-04-22     44380.15
# 17   2003-05-09      3101.40
# 18   2003-05-12     35826.33
# 19   2003-05-20     45864.03
# 20   2003-05-21     16700.47
# 21   2003-05-25     50824.66
# 22   2003-05-31      7565.08
# 23   2003-06-05     14571.44
# 24   2003-06-06     32641.98
# 25   2003-06-13     57131.92
# 26   2003-06-18     58841.35
# 27   2003-06-25     17032.29
# 28   2003-07-05      2880.00
# 29   2003-07-06      6036.96
# ..          ...          ...
# ...

# %% [markdown]
# ## 4. Report the products that have not been sold.

# %%
run("""
    SELECT DISTINCT
    p.productCode,
    p.productName,
    o.orderNumber
    FROM
    products p
    LEFT JOIN
    orderdetails o
    ON 
    p.productCode = o.productCode
    WHERE o.orderNumber is null
""")
# Out:
#   productCode        productName orderNumber
# 0    S18_3233  1985 Toyota Supra        None

# %% [markdown]
# ## 5. List the amount paid by each customer.

# %%
run("""
    SELECT
    c.customerNumber,
    c.customerName,
    SUM(p.amount)
    FROM
    customers c
    INNER JOIN
    payments p
    ON
    c.customerNumber = p.customerNumber
    GROUP BY c.customerNumber
""")
# Out:
#     customerNumber                        customerName  SUM(p.amount)
# 0              103                   Atelier graphique       22314.36
# 1              112                  Signal Gift Stores       80180.98
# 2              114          Australian Collectors, Co.      180585.07
# 3              119                   La Rochelle Gifts      116949.68
# 4              121                  Baane Mini Imports      104224.79
# 5              124        Mini Gifts Distributors Ltd.      584188.24
# 6              128                Blauer See Auto, Co.       75937.76
# 7              129                     Mini Wheels Co.       66710.56
# 8              131                   Land of Toys Inc.      107639.94
# 9              141              Euro+ Shopping Channel      715738.98
# 10             144            Volvo Model Replicas, Co       43680.65
# 11             145            Danish Wholesale Imports      107446.50
# ...

# %% [markdown]
# ## 6. How many orders have been placed by Herkku Gifts?

# %%
run("""
    SELECT
    c.customerNumber,
    c.customerName,
    count(o.orderNumber)
    FROM
    customers c
    INNER JOIN
    orders o
    ON
    c.customerNumber = o.customerNumber
    WHERE c.customerName = 'Herkku Gifts'
    GROUP BY c.customerNumber
""")
# Out:
#    customerNumber  customerName  count(o.orderNumber)
# 0             167  Herkku Gifts                     3

# %% [markdown]
# ## 7. Who are the employees in Boston?

# %%
run("""
    SELECT
    e.employeeNumber,
    CONCAT(e.firstName, e.lastName)
    FROM employees e
    INNER JOIN
    offices o
    ON
    e.officeCode = o.officeCode
    WHERE o.city = 'Boston'
""")
# Out:
#    employeeNumber CONCAT(e.firstName, e.lastName)
# 0            1188                   JulieFirrelli
# 1            1216                  StevePatterson

# %% [markdown]
# ## 8. Report those payments greater than \$100,000. Sort the report so the customer who made the highest payment appears first.

# %%
run("""
    SELECT
    c.customerNumber,
    c.customerName,
    SUM(p.amount) Total_Payment
    FROM
    customers c
    INNER JOIN
    payments p
    ON
    c.customerNumber = p.customerNumber
    GROUP BY c.customerNumber
    HAVING Total_Payment > 100000
    ORDER BY Total_Payment DESC
""")
# Out:
#     customerNumber                  customerName  Total_Payment
# 0              141        Euro+ Shopping Channel      715738.98
# 1              124  Mini Gifts Distributors Ltd.      584188.24
# 2              114    Australian Collectors, Co.      180585.07
# 3              151            Muscle Machine Inc      177913.95
# 4              148       Dragon Souveniers, Ltd.      156251.03
# 5              323    Down Under Souveniers, Inc      154622.08
# 6              187                AV Stores, Co.      148410.09
# 7              276       Anna's Decorations, Ltd      137034.22
# 8              321      Corporate Gift Ideas Co.      132340.78
# 9              146        Saveley & Henriot, Co.      130305.35
# 10             278                 Rovelli Gifts      127529.69
# 11             353            Reims Collectables      126983.19
# 12             119             La Rochelle Gifts      116949.68
# 13             363  Online Diecast Creations Co.      116449.29
# ...

# %% [markdown]
# ## 9. List the value of 'On Hold' orders.

# %%
run("""
    SELECT DISTINCT
    o.orderNumber,
    o.orderDate,
    o.requiredDate,
    o.status,
    o.comments,
    o.customerNumber,
    SUM(od.quantityOrdered*od.priceEach) Value_Of_On_Hold_Orders
    FROM 
    orders o
    INNER JOIN
    orderdetails od
    ON
    o.orderNumber = od.orderNumber
    WHERE o.status = 'on hold'
    GROUP BY o.orderNumber
""")
# Out:
#    orderNumber   orderDate requiredDate   status  \
# 0        10334  2004-11-19   2004-11-28  On Hold
# 1        10401  2005-04-03   2005-04-14  On Hold
# 2        10407  2005-04-22   2005-05-04  On Hold
# 3        10414  2005-05-06   2005-05-13  On Hold
#
#                                             comments  customerNumber  \
# 0  The outstaniding balance for this customer exc...             144
# 1  Customer credit limit exceeded. Will ship when...             328
# 2  Customer credit limit exceeded. Will ship when...             450
# 3  Customer credit limit exceeded. Will ship when...             362
#
#    Value_Of_On_Hold_Orders
# 0                 23014.17
# 1                 43525.04
# 2                 52229.55
# 3                 50806.85

# %% [markdown]
# ## 10. Report the number of orders 'On Hold' for each customer.

# %%
run("""
    SELECT
    c.customerNumber,
    c.customerName,
    COUNT(CASE WHEN o.status = 'On Hold' THEN 1 END) On_Hold_Orders
    FROM
    customers c
    LEFT JOIN
    orders o
    ON
    c.customerNumber = o.customerNumber
    GROUP BY c.customerNumber
    ORDER BY On_Hold_Orders DESC, c.customerNumber
""")
# Out:
#      customerNumber                        customerName  On_Hold_Orders
# 0               144            Volvo Model Replicas, Co               1
# 1               328             Tekni Collectables Inc.               1
# 2               362                   Gifts4AllAges.com               1
# 3               450           The Sharp Gifts Warehouse               1
# 4               103                   Atelier graphique               0
# 5               112                  Signal Gift Stores               0
# 6               114          Australian Collectors, Co.               0
# 7               119                   La Rochelle Gifts               0
# 8               121                  Baane Mini Imports               0
# 9               124        Mini Gifts Distributors Ltd.               0
# 10              125                  Havel & Zbyszek Co               0
# 11              128                Blauer See Auto, Co.               0
# ...

# %% [markdown]
# # Many to many relationship

# %% [markdown]
# ## 1. List products sold by order date.

# %%
run("""
    SELECT
    o.orderDate,
    od.productCode,
    p.productName
    FROM
    orders o
    INNER JOIN
    orderdetails od
    ON
    o.orderNumber = od.orderNumber
    INNER JOIN
    products p
    ON
    od.productCode = p.productCode
    ORDER BY o.orderDate
""")
# Out:
#        orderDate productCode                                  productName
# 0     2003-01-06    S18_1749                     1917 Grand Touring Sedan
# 1     2003-01-06    S18_2248                           1911 Ford Town Car
# 2     2003-01-06    S24_3969             1936 Mercedes Benz 500k Roadster
# 3     2003-01-06    S18_4409          1932 Alfa Romeo 8C2300 Spider Sport
# 4     2003-01-09    S18_2325                    1932 Model A Ford J-Coupe
# 5     2003-01-09    S18_2795                       1928 Mercedes-Benz SSK
# 6     2003-01-09    S24_1937                  1939 Chevrolet Deluxe Coupe
# 7     2003-01-09    S24_2022    1938 Cadillac V-16 Presidential Limousine
# 8     2003-01-10    S18_1342                         1937 Lincoln Berline
# 9     2003-01-10    S18_1367     1936 Mercedes-Benz 500K Special Roadster
# 10    2003-01-29    S24_4258                        1936 Chrysler Airflow
# 11    2003-01-29    S12_1666                               1958 Setra Bus
# ...

# %% [markdown]
# ## 2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck.

# %%
run("""
    SELECT
    o.orderDate,
    o.orderNumber,
    od.productCode,
    p.productName
    FROM
    orders o
    INNER JOIN
    orderdetails od
    ON
    o.orderNumber = od.orderNumber
    INNER JOIN
    products p
    ON
    od.productCode = p.productCode
    WHERE
    p.productName = '1940 Ford Pickup Truck'
    ORDER BY o.orderDate DESC
""")
# Out:
#      orderDate  orderNumber productCode             productName
# 0   2005-05-31        10424    S18_1097  1940 Ford Pickup Truck
# 1   2005-05-01        10411    S18_1097  1940 Ford Pickup Truck
# 2   2005-03-09        10391    S18_1097  1940 Ford Pickup Truck
# 3   2005-02-17        10381    S18_1097  1940 Ford Pickup Truck
# 4   2005-01-20        10370    S18_1097  1940 Ford Pickup Truck
# 5   2004-12-10        10357    S18_1097  1940 Ford Pickup Truck
# 6   2004-11-29        10347    S18_1097  1940 Ford Pickup Truck
# 7   2004-11-18        10333    S18_1097  1940 Ford Pickup Truck
# 8   2004-11-04        10322    S18_1097  1940 Ford Pickup Truck
# 9   2004-10-21        10312    S18_1097  1940 Ford Pickup Truck
# 10  2004-10-11        10304    S18_1097  1940 Ford Pickup Truck
# 11  2004-09-08        10291    S18_1097  1940 Ford Pickup Truck
# 12  2004-08-17        10280    S18_1097  1940 Ford Pickup Truck
# 13  2004-07-19        10270    S18_1097  1940 Ford Pickup Truck
# ...

# %% [markdown]
# ## 3. List the names of customers and their corresponding order number where a particular order from that customer has a value greater than $25,000?

# %%
run("""
    SELECT
    c.customerNumber,
    c.customerName,
    o.orderNumber,
    SUM(od.quantityOrdered*od.priceEach) as Value
    FROM
    customers c
    INNER JOIN
    orders o
    ON
    c.customerNumber = o.customerNumber
    INNER JOIN
    orderdetails od
    ON
    o.orderNumber = od.orderNumber
    GROUP BY od.orderNumber
    HAVING Value > 25000
""")
# Out:
#      customerNumber                        customerName  orderNumber     Value
# 0               112                  Signal Gift Stores        10124  32641.98
# 1               112                  Signal Gift Stores        10278  33347.88
# 2               114          Australian Collectors, Co.        10120  45864.03
# 3               114          Australian Collectors, Co.        10223  44894.74
# 4               114          Australian Collectors, Co.        10342  40265.60
# 5               114          Australian Collectors, Co.        10347  41995.62
# 6               119                   La Rochelle Gifts        10275  47924.19
# 7               119                   La Rochelle Gifts        10375  49523.67
# 8               119                   La Rochelle Gifts        10425  41623.44
# 9               121                  Baane Mini Imports        10103  50218.95
# 10              121                  Baane Mini Imports        10325  34638.14
# ...

# %% [markdown]
# ## 4. Are there any products that appear on all orders?

# %% [markdown]
# Nope

# %% [markdown]
# ## 5. List the names of products sold at less than 80% of the MSRP.

# %%
run("""
    SELECT
    productName as productName_sold_less_than80percentMSRP,
    (od.priceEach/p.MSRP)*100 as Price_Percentage_from_MSRP,
    orderNumber as in_this_orderNumber
    FROM
    products p
    INNER JOIN
    orderdetails od
    ON
    p.productCode = od.productCode
    HAVING Price_Percentage_from_MSRP < 80
""")
# Out:
#         productName_sold_less_than80percentMSRP  Price_Percentage_from_MSRP  \
# 0                         1996 Moto Guzzi 1100i                   79.998318
# 1                               1993 Mazda RX-7                   79.998587
# 2                          1937 Lincoln Berline                   79.998053
# 3                         1965 Aston Martin DB5                   79.998393
# 4                         1965 Aston Martin DB5                   79.998393
# 5                   1980s Black Hawk Helicopter                   79.998732
# 6                   1980s Black Hawk Helicopter                   79.998732
# 7                            1911 Ford Town Car                   79.996696
# 8                                P-51-D Mustang                   79.995265
# 9                                P-51-D Mustang                   79.995265
# 10                  1992 Ferrari 360 Spider red                   79.998819
# ...

# %% [markdown]
# ## 6. Reports those products that have been sold with a markup of 100% or more (i.e., the priceEach is at least twice the buyPrice)

# %%
run("""
    SELECT
    od.productCode,
    p.productName,
    priceEach,
    (priceEach-buyPrice)/buyPrice*100 as Percentage_Margin,
    orderNumber
    FROM
    orderdetails od
    INNER JOIN
    products p
    ON od.productCode = p.productCode
    Having Percentage_Margin >= 100 
    ORDER BY productCode, PriceEach, orderNumber
""")
# Out:
#     productCode                           productName  priceEach  \
# 0      S10_1949              1952 Alpine Renault 1300     197.16
# 1      S10_1949              1952 Alpine Renault 1300     199.30
# 2      S10_1949              1952 Alpine Renault 1300     201.44
# 3      S10_1949              1952 Alpine Renault 1300     201.44
# 4      S10_1949              1952 Alpine Renault 1300     203.59
# 5      S10_1949              1952 Alpine Renault 1300     203.59
# 6      S10_1949              1952 Alpine Renault 1300     205.73
# 7      S10_1949              1952 Alpine Renault 1300     205.73
# 8      S10_1949              1952 Alpine Renault 1300     205.73
# 9      S10_1949              1952 Alpine Renault 1300     205.73
# 10     S10_1949              1952 Alpine Renault 1300     207.87
# 11     S10_1949              1952 Alpine Renault 1300     210.01
# 12     S10_1949              1952 Alpine Renault 1300     212.16
# ...

# %% [markdown]
# ## 7. List the products ordered on a Monday.

# %%
run("""
    SELECT
    p.productName,
    o.orderDate,
    DAYNAME(o.orderDate) as Day
    FROM
    orders o
    INNER JOIN
    orderdetails od
    ON
    o.orderNumber = od.orderNumber
    INNER JOIN
    products p
    ON
    od.productCode = p.productCode
    HAVING Day = 'Monday'
""")
# Out:
#                                productName   orderDate     Day
# 0    1969 Harley Davidson Ultimate Chopper  2003-02-24  Monday
# 1    1969 Harley Davidson Ultimate Chopper  2003-08-25  Monday
# 2    1969 Harley Davidson Ultimate Chopper  2003-12-01  Monday
# 3    1969 Harley Davidson Ultimate Chopper  2004-04-05  Monday
# 4    1969 Harley Davidson Ultimate Chopper  2004-06-28  Monday
# 5    1969 Harley Davidson Ultimate Chopper  2004-11-15  Monday
# 6                 1952 Alpine Renault 1300  2003-03-24  Monday
# 7                 1952 Alpine Renault 1300  2003-10-20  Monday
# 8                 1952 Alpine Renault 1300  2004-07-19  Monday
# 9                 1952 Alpine Renault 1300  2004-10-11  Monday
# 10                1952 Alpine Renault 1300  2004-11-29  Monday
# 11                   1996 Moto Guzzi 1100i  2003-02-24  Monday
# 12                   1996 Moto Guzzi 1100i  2003-08-25  Monday
# 13                   1996 Moto Guzzi 1100i  2003-12-01  Monday
# ...

# %% [markdown]
# ## 8. What is the quantity on hand for products listed on 'On Hold' orders?

# %%
run("""
    SELECT DISTINCT
    od.productCode,
    o.status,
    SUM(od.quantityOrdered) as quantity_on_hand
    FROM 
    orders o
    INNER JOIN
    orderdetails od
    ON
    o.orderNumber = od.orderNumber
    WHERE o.status = 'on hold'
    GROUP BY od.productCode
    ORDER BY productCode
""")
# Out:
#    productCode   status  quantity_on_hand
# 0     S10_4757  On Hold              49.0
# 1     S10_4962  On Hold              26.0
# 2     S18_1589  On Hold              59.0
# 3     S18_1749  On Hold              76.0
# 4     S18_2248  On Hold              42.0
# 5     S18_2319  On Hold              46.0
# 6     S18_2432  On Hold              34.0
# 7     S18_2581  On Hold              42.0
# 8     S18_2870  On Hold              41.0
# 9     S18_3029  On Hold              44.0
# 10    S18_3140  On Hold              41.0
# 11    S18_3232  On Hold              20.0
# 12    S18_3259  On Hold              48.0
# 13    S18_4409  On Hold               6.0
# 14    S18_4522  On Hold              56.0
# 15    S18_4600  On Hold              49.0
# 16    S18_4933  On Hold              66.0
# 17    S24_1046  On Hold              26.0
# 18    S24_1628  On Hold              64.0
# 19    S24_1785  On Hold              38.0
# 20    S24_2011  On Hold              43.0
# ...
